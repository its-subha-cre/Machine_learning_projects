# %%
pip install --upgrade pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as  np
from sklearn import linear_model

# %%
df=pd.read_csv('hiring.csv')

# %%
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   experience                  6 non-null      object
#  1   test_score(out of 10)       7 non-null      float64
#  2   interview_score(out of 10)  8 non-null      int64
#  3   salary($)                   8 non-null      int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 388.0+ bytes

# %%
df.rename(columns={'test_score(out of 10)':'test'},inplace=True)

# %%
df['experience']=df.experience.fillna('')
df['test']=df.test.fillna('')

# %%
df
# Out:
#   experience  test  interview_score(out of 10)  salary($)
# 0              8.0                           9      50000
# 1              8.0                           6      45000
# 2       five   6.0                           7      60000
# 3        two  10.0                          10      65000
# 4      seven   9.0                           6      70000
# 5      three   7.0                          10      62000
# 6        ten                                 7      72000
# 7     eleven   7.0                           8      80000

# %%
df.loc[0,'experience']='one'

# %%
df
# Out:
#   experience  test  interview_score(out of 10)  salary($)
# 0        one   8.0                           9      50000
# 1              8.0                           6      45000
# 2       five   6.0                           7      60000
# 3        two  10.0                          10      65000
# 4      seven   9.0                           6      70000
# 5      three   7.0                          10      62000
# 6        ten                                 7      72000
# 7     eleven   7.0                           8      80000

# %%
if df.iloc[1].experience =='':
    print(type(df.index))
# Out:
# <class 'pandas.core.indexes.range.RangeIndex'>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
df.iloc[1].experience
# Out:
# ''

# %%
df.loc[1,'experience']='two'

# %%
df
# Out:
#   experience  test  interview_score(out of 10)  salary($)
# 0        one   8.0                           9      50000
# 1        two   8.0                           6      45000
# 2       five   6.0                           7      60000
# 3        two  10.0                          10      65000
# 4      seven   9.0                           6      70000
# 5      three   7.0                          10      62000
# 6        ten                                 7      72000
# 7     eleven   7.0                           8      80000

# %%
for i in df.index:
    if df.loc[i,'test']=='':
        df.loc[i,'test']=11.0

# %%
df
# Out:
#   experience  test  interview_score(out of 10)  salary($)
# 0        one   8.0                           9      50000
# 1        two   8.0                           6      45000
# 2       five   6.0                           7      60000
# 3        two  10.0                          10      65000
# 4      seven   9.0                           6      70000
# 5      three   7.0                          10      62000
# 6        ten  11.0                           7      72000
# 7     eleven   7.0                           8      80000

# %%
df.rename(columns={'interview_score(out of 10)':'interview','salary($)':'salary'},inplace=True)
df
# Out:
#   experience  test  interview  salary
# 0        one   8.0          9   50000
# 1        two   8.0          6   45000
# 2       five   6.0          7   60000
# 3        two  10.0         10   65000
# 4      seven   9.0          6   70000
# 5      three   7.0         10   62000
# 6        ten  11.0          7   72000
# 7     eleven   7.0          8   80000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   experience  8 non-null      object
#  1   test        8 non-null      float64
#  2   interview   8 non-null      int64
#  3   salary      8 non-null      int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 388.0+ bytes

# %%
df['test']=df['test'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   experience  8 non-null      object
#  1   test        8 non-null      int64
#  2   interview   8 non-null      int64
#  3   salary      8 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 388.0+ bytes

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['test','interview']],df['salary'])
# Out:
# LinearRegression()

# %%
reg.predict([[4,7]])
# Out:
# C:\Users\subha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([56562.58503401])

# %%
n=reg.coef_

# %%
reg.intercept_
# Out:
# np.float64(48512.24489795918)

# %%
n[0]
# Out:
# np.float64(1448.2993197278918)

# %%
n[1]
# Out:
# np.float64(322.44897959183686)

# %%
l=[]
l.append(n[0])
l.append(n[1])
l.append(reg.intercept_)

# %%
import pickle
pickle.dump(l,open('li.pkl','wb'))
pickle.dump(df,open('df.pkl','wb'))

# %% [markdown]
# print(np.ndarray.size())

# %%
print(np.ndarray.size())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 print(np.ndarray.size())
#
# TypeError: 'getset_descriptor' object is not callable

# %%
l=[]
for i in n:
    l.append(i)
l
# Out:
# [np.float64(1448.2993197278918), np.float64(322.44897959183686)]
