# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_wine

# %%
wine=load_wine()

# %%
dir(wine)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'target', 'target_names']

# %%
df=pd.DataFrame(wine.data,columns=wine.feature_names)

# %%
wine.feature_names
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(0.95)

# %%
df_pca=pca.fit_transform(df)

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df['target']=wine.target

# %%
wine.target_names
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %%
a=cross_val_score(RandomForestClassifier(n_estimators=100),df_pca,df.target,cv=5).mean()
b=cross_val_score(LogisticRegression(),df_pca,df.target,cv=5).mean()
c=cross_val_score(DecisionTreeClassifier(),df_pca,df.target,cv=5).mean()
d=cross_val_score(SVC(),df_pca,df.target,cv=5).mean()
e=cross_val_score(KNeighborsClassifier(n_neighbors=15),df_pca,df.target,cv=5).mean()
f=cross_val_score(GaussianNB(),df_pca,df.target,cv=5).mean()
l=[a,b,c,d,e,f]

# %%
l
# Out:
# [np.float64(0.7079365079365079),
#  np.float64(0.703015873015873),
#  np.float64(0.7079365079365079),
#  np.float64(0.6973015873015873),
#  np.float64(0.6968253968253968),
#  np.float64(0.7087301587301588)]

# %%
from sklearn.ensemble import BaggingClassifier
bag=BaggingClassifier(estimator=KNeighborsClassifier(n_neighbors=15), n_estimators=10)
z=cross_val_score(bag,df_pca,df.target,cv=5).mean()
z
# Out:
# np.float64(0.6917460317460318)
